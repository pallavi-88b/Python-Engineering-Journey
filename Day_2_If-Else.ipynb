# %% [markdown]
# ## Question 01 : Take a number as an input and check whether it is even or not.

# %%
num = int(input("Enter a number :"))
if num % 2 == 0:
    print("The number is even.")
else: 
    print("The number is odd.")
# Out:
# Enter a number : 108
# The number is even.

# %% [markdown]
# ## Question 02: Take a number as input and check whether it is positive, negative, or zero.

# %%
num = int(input("Enter a number :"))
if num > 0 :
    print("The number is positive.")
elif num < 0 :
    print("The number is negative.")
else :
    print("The number is zero.")
# Out:
# Enter a number : 0
# The number is zero.

# %% [markdown]
# ## Question 03: Take two number as input and print the largest number.

# %%
num_1 = int(input("Enter a number :"))
num_2 = int(input("Enter second number :"))
if num_1 > num_2 :
    print("The first number is greater :",num_1)
else :
    print("The second number is greater :",num_2)
# Out:
# Enter a number : 67
# Enter second number : 58
# The first number is greater : 67

# %% [markdown]
# ## Question 04: Take three numbers as input and find the largest number.

# %%
num_1 = int(input("Enter first number :"))
num_2 = int(input("Enter second number :"))
num_3 = int(input("Enter third number :"))
if num_1 > num_2 and num_1 > num_3 :
    print("The number 1 is larger :",num_1)
elif num_2 > num_1 and num_2 > num_3 :
    print("The number 2 is  larger :",num_2)
else :
    print("The number 3 is larger :",num_3)
# Out:
# Enter first number : 90
# Enter second number : 65
# Enter third number : 34
# The number 1 is larger : 90

# %% [markdown]
# ## Question 05: Take marks as input and assign a grade based on the marks.

# %%
num = int(input("Enter marks out of 100 :"))
if num >= 80 :
    print("Grade A.")
elif num >= 60 and num < 80 :
    print("Grade B.")
elif num >= 40 and num < 60 :
    print("Grade C.")
else :
    print("Grade D.")
# Out:
# Enter marks out of 100 : 89
# Grade A.

# %% [markdown]
# ## Question 06: Take a year as input and check whether it is a leap year.

# %%
num = int(input("Enter year :"))
if(num % 4 == 0 and num % 100 != 0 )or num % 400 == 0 :
    print(f'{num} is leap year.')
else :
    print(f'{num} is not leap year.')
# Out:
# Enter year : 1900
# 1900 is not leap year.

# %% [markdown]
# ## Question 07: Take age as input and check whether a person is eligible to vote.

# %%
num = int(input("Enter your age :"))
if num >= 18 :
    print("You are eligible.")
else :
    print("You are not eligible.")
# Out:
# Enter your age : 43
# You are eligible.

# %% [markdown]
# ## Question 08: Create alogin system that checks whether the entered username and password are correct.

# %%
username = "Pallavi08"
password = "Test@123"
num_1 = str(input("Enter username :"))
num_2 = str(input("Enter password :"))

if username == num_1  :
    print("Enter username is correct.")
    if password == num_2 :
        print("Enter password is correct.")
    else :
        print("Enter password is incorrect.")
else :
    print("Enter username is incorrect.")
# Out:
# Enter username : Pallavi08
# Enter password : test34
# Enter username is correct.
# Enter password is incorrect.

# %% [markdown]
# ## Question 09: Take account balance and withdrawl amount as input and check whether the ATM withdrawl is possible.

# %%
acc_balance = float(input("Enter account balance :"))
amount = float(input("Enter amount :"))
if acc_balance > amount :
    print("ATM withdrawl is possible.")
else :
    print("ATM withdrawl is not possible.")
# Out:
# Enter account balance : 7000
# Enter amount : 4500
# ATM withdrawl is possible.

# %% [markdown]
# ## Question 10: Take electricity units as input and calculate rthe bill using different rates for different consumption slabs.

# %%
num = int(input("Enter electricity units :"))
if num > 0 and num <=50 :
    print("Your bill amount :",num *10 )
elif num > 50 and num <=100 :
    print("Your bill amount :",num *15 )
elif num > 100 and num <=150 :
    print("Your bill amount :",num *20 )
# Out:
# Enter electricity units : 77
# Your bill amount : 1155

# %% [markdown]
# ## Question 11: Take annual income as input and calculate tax according to different income slabs.

# %%
num = float(input("Enter annual income :"))
if num > 0 and num <= 10000 :
    print("Tax on your annual income :",num *0.10 )
elif num > 10000 and num <=20000 :
    print("Tax on your annual income :",num *0.15 )
elif num > 20000 and num <=50000 :
    print("Tax on your annual income :",num *0.20 )
else :
    print("Tax on your annual income :",num * 0.30)
# Out:
# Enter annual income : 56000
# Tax on your annual income : 16800.0

# %% [markdown]
# ## Question 12: Take age and citizenship status as input and check whether the person is eligible for a driving license.

# %%
num = int(input("Enter your age :"))
num2 = str(input("Enter your citizenship :"))

if num >= 18 and ( num2 == India or num2 == india or num2 == INDIA ) :
    print("You are eligible for driving license.")
else :
    print("You are not eligible for driving license.")
# Out:
# Enter your age : 15
# Enter your citizenship : india
# You are not eligible for driving license.

# %% [markdown]
# ## Question 13: Take three sides as input and check whether they can form a valid triangle.

# %%
num1 = int(input("Enter first side of triangle :"))
num2 = int(input("Enter second side of triangle :"))
num3 = int(input("Enter third side of triangle :"))

if num1 + num2 > num3 and num1 + num3 > num2 and num2 + num3 > num1 :
    print("The triangle is valid.")
else :
    print("The triangle is not valid.")
# Out:
# Enter first side of triangle : 8
# Enter second side of triangle : 3
# Enter third side of triangle : 9
# The triangle is valid.

# %% [markdown]
# ## Question 14: Take a character as input and determine whether it is vowel, consonent, digit, or special character.

# %%
x = str(input("Enter a character :"))

if (x == 'a' or x == 'e' or x == 'i' or x == 'o' or x == 'u' or x == 'A' or x == 'E' or x == 'I' or x == 'O' or x == 'U' ):
    print("Character is vowel")
elif(x >= '0' and x <= '9'):
     print("Character is digit")
elif (x >= 'a' and x<= 'z')or (x>= 'A' and x<='Z'):
    print("Character is consonent.")
#elif (x == '@' or x == '#' or x == '%' or x == '&' or x == '*'):
   #  print("Character is special character.")

else:
    print("Character is special character.")
# Out:
# Enter a character : $
# Character is alphabet

# %% [markdown]
# ## Question 15: Take a number as input and check whether it is divisible by both 3 and 5.

# %%
num = int(input("Enter a number :"))
if num % 5 == 0:
    print("The number is divisible by 5.")
elif num % 3 == 0:
    print("The number is divisible by 3.")
else :
    print("The number is not divisiblr by both 5 and 3.")
# Out:
# Enter a number : 50
# The number is divisible by 5.

# %% [markdown]
# ## Question 16: Take cost price and selling price as input and determine whether there is a profit, loss, or no profit/loss.

# %%
cp = float(input("Enter cost price :"))
sp = float(input("Enter selling price :"))
if( sp - cp > 0 ):
    print("There is a profit.)
elif( cp - sp < 0 ):
    print("There is a loss.")
else :
    print("There is no profit or loss.")
# Out:
# Enter cost price : 800
# Enter selling price : 900
# There is a profit.

# %% [markdown]
# ## Question 17: Create a discount system where the discount percentage changes according to the purchase amount.

# %%
x = float(input("Enter your purchase amount :"))
if x >= 0 and x <= 500 :
    print("The discount on your amount :", x* 0.10)
elif  x >= 500 and x <= 1000 :
    print("The discount on your amount :", x* 0.15)
elif  x >= 1000 and x <= 2000 :
    print("The discount on your amount :", x* 0.20)
else :
    print("The dicsount on your amount :", x* 0.25)
# Out:
# Enter your purchase amount : 1800
# The discount on your amount : 360.0

# %% [markdown]
# ## Question 18: Take a password as input and checks whether it satisfies basic conditions for password strength.

# %%
password = input("Enter your password :")
if len(password)>= 8 :
    print("Satisfy password strenght.")
else :
    print("Your password does not satisfies strenght.")
# Out:
# Enter your password : 567666
# Your password does not satisfies strenght.

# %% [markdown]
# ## Question 19: Take a person's age and ticket type as input and calculate the ticket price using appropriate  conditions.

# %%
x = int(input("Enter your age :"))
y = str(input("Enter your ticket type :"))
if x >= 18 and y == "reserved" :
    print("your ticket price :800" )
elif x < 18 and y== "un_reserved" :
    print("your ticket price :1000" )
elif x < 18 and y == "platform" :
    print("your ticket price :1500" )
# Out:
# Enter your age : 20
# Enter your ticket type : reserved
# your ticket price :800

# %% [markdown]
# ## Question 20: Create a menu-driven calculator that performs addition, subtraction, multiplication, or division based on the user's choice.

# %%
print("1 for addition.")
print("2 for substraction.")
print("3 for multiplication.")
print("4 for division.")

check = int(input("Enter your choice :"))
x = float(input("Enter first number :"))
y = float(input("Enter second number :"))

if check == 1 :
    print("Addition :", x + y)
elif check == 2 :
    print("Substraction :", x - y )
elif check == 3  :
    print("Multiplication :", x*y)
elif check == 4 :
    if y!= 0 :
        print("Division :",x / y)
    else :
        print("Cannot be divide by zero.")
else :
    print("Invaild input.")
# Out:
# 1 for addition.
# 2 for substraction.
# 3 for multiplication.
# 4 for division.
# Enter your choice : 2
# Enter first number : 470
# Enter second number : 500
# Substraction : -30.0

# %% [markdown]
# ## Mini Project : Smart ATM Simulator

# %%
balance = 10000
pin = 1234
e_pin = int(input("Enter your pin :"))

if e_pin == pin :
    print("\n-----------smart atm----------")
    print("1. check balance")
    print("2. deposit money")
    print("3. withdrawl money ")
    print("4. exit")

    choice = int(input("Enter your choice :"))
    if choice == 1 :
       print("Your balance amount :",balance)
    elif choice == 2 :
          amount = float(input("Enter deposit amount :"))
          if amount >0 :
              balance += amount
              print("Amount deposited , new balance :", balance)
          else :
              print("Invalid amount.")
    elif  choice == 3 :
          amount = float(input("Enter withdrawl amount :"))
          if amount < 0 :
              print("Invalid amount.")   
          elif amount > balance :
              print("Insufficient balance.")
          else :
              print("Remaining balance :", balance - amount)
    elif  choice == 4 :
      print("Thank you.")
    else :
      print("Invalid choice.")
else :
    print("Incorrect pin.")
# Out:
# Enter your pin : 1234
# -----------smart atm----------
# 1. check balance
# 2. deposit money
# 3. withdrawl money
# 4. exit
# Enter your choice : 3
# Enter withdrawl amount : 4500
# Remaining balance : 5500.0
