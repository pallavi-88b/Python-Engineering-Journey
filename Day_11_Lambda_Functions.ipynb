# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟏 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙤𝙣𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙞𝙩𝙨 𝙨𝙦𝙪𝙖𝙧𝙚.

# %%
num = int(input("Enter Number: "))
square = lambda num: num ** 2
square(num)
# Out:
# Enter Number:  4
# 16

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟐 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙬𝙤 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙩𝙝𝙚𝙞𝙧 𝙨𝙪𝙢.

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
total = lambda a,b: a + b
total(a,b)
# Out:
# Enter Number:  6
# Enter Number:  4
# 10

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟑 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙬𝙤 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙩𝙝𝙚 𝙡𝙖𝙧𝙜𝙚𝙧 𝙣𝙪𝙢𝙗𝙚𝙧.

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
large = lambda a ,b: a if a > b else b
large(a,b)
# Out:
# Enter Number:  55
# Enter Number:  89
# 89

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟒 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙤𝙣𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨: "𝙀𝙫𝙚𝙣" 𝙞𝙛 𝙩𝙝𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙨 𝙚𝙫𝙚𝙣 "𝙊𝙙𝙙" 𝙞𝙛 𝙩𝙝𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙨 𝙤𝙙𝙙.

# %%
num = int(input("Enter Number: "))
check = lambda num: "even" if num % 2 == 0 else "odd"
check(num)
# Out:
# Enter Number:  49
# 'odd'

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟓 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 "𝙋𝙤𝙨𝙞𝙩𝙞𝙫𝙚", "𝙉𝙚𝙜𝙖𝙩𝙞𝙫𝙚", 𝙤𝙧 "𝙕𝙚𝙧𝙤".

# %%
num = int(input("Enter Number: "))
check = lambda num:"positive" if num>0 else "Negative" if num<0  else "Zero"
check(num)
# Out:
# Enter Number:  -25
# 'Negative'

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟔 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙞𝙩𝙨 𝙖𝙗𝙨𝙤𝙡𝙪𝙩𝙚 𝙫𝙖𝙡𝙪𝙚.

# %%
a = int(input("Enter Number: "))
check =lambda a: a if a>0 else a* -1
check(a)
# Out:
# Enter Number:  -45
# 45

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟕 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝟏𝟎% 𝙤𝙛 𝙩𝙝𝙖𝙩 𝙣𝙪𝙢𝙗𝙚𝙧.

# %%
num = int(input("Enter Number: "))
check = lambda num: num* 0.10
check(num)
# Out:
# Enter Number:  100
# 10.0

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟖 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙥𝙧𝙞𝙘𝙚 𝙖𝙣𝙙 𝙖𝙥𝙥𝙡𝙞𝙚𝙨 𝙖 𝟏𝟎% 𝙙𝙞𝙨𝙘𝙤𝙪𝙣𝙩, 𝙩𝙝𝙚𝙣 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙩𝙝𝙚 𝙛𝙞𝙣𝙖𝙡 𝙥𝙧𝙞𝙘𝙚.

# %%
num = int(input("Enter price: "))
check = lambda num: num - (num*0.10)
check(num)
# Out:
# Enter price:  1000
# 900.0

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟗 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙬𝙤 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙩𝙝𝙚𝙞𝙧 𝙖𝙫𝙚𝙧𝙖𝙜𝙚.

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
check = lambda a,b: (a+b)/2
check(a,b)
# Out:
# Enter Number:  10
# Enter Number:  20
# 15.0

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟎 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙝𝙧𝙚𝙚 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙩𝙝𝙚𝙞𝙧 𝙡𝙖𝙧𝙜𝙚𝙨𝙩 𝙣𝙪𝙢𝙗𝙚𝙧.

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
c = int(input("Enter Number: "))
check = lambda a,b,c: a if a>b and a> c else b if b>a and b>c else c
check(a,b,c)
# Out:
# Enter Number:  34
# Enter Number:  67
# Enter Number:  45
# 67

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟏 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 "𝙋𝙖𝙨𝙨" 𝙞𝙛 𝙢𝙖𝙧𝙠𝙨 𝙖𝙧𝙚 𝟒𝟎 𝙤𝙧 𝙖𝙗𝙤𝙫𝙚, 𝙤𝙩𝙝𝙚𝙧𝙬𝙞𝙨𝙚 "𝙁𝙖𝙞𝙡".

# %%
num = int(input("Enter Number: "))
check = lambda num: "pass"if num > 40 else "fail"
check(num)
# Out:
# Enter Number:  80
# 'pass'

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟐 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙞𝙩𝙨 𝙨𝙦𝙪𝙖𝙧𝙚 𝙞𝙛 𝙞𝙩 𝙞𝙨 𝙚𝙫𝙚𝙣, 𝙤𝙩𝙝𝙚𝙧𝙬𝙞𝙨𝙚 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙞𝙩𝙨 𝙘𝙪𝙗𝙚.

# %%
num = int(input("Enter Number: "))
check = lambda num: num*num if num % 2 == 0 else num*num*num
check(num)
# Out:
# Enter Number:  5
# 125

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟑 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙬𝙤 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 "𝙀𝙦𝙪𝙖𝙡" 𝙞𝙛 𝙗𝙤𝙩𝙝 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙧𝙚 𝙚𝙦𝙪𝙖𝙡, 𝙤𝙩𝙝𝙚𝙧𝙬𝙞𝙨𝙚 "𝙉𝙤𝙩 𝙀𝙦𝙪𝙖𝙡".

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
check = lambda a,b: "equal"if a == b else "not equal"
check(a,b)
# Out:
# Enter Number:  89
# Enter Number:  89
# 'equal'

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟒 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨: "𝙎𝙢𝙖𝙡𝙡" 𝙞𝙛 𝙩𝙝𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙨 𝙡𝙚𝙨𝙨 𝙩𝙝𝙖𝙣 𝟓𝟎 "𝙇𝙖𝙧𝙜𝙚" 𝙞𝙛 𝙩𝙝𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙨 𝟓𝟎 𝙤𝙧 𝙢𝙤𝙧𝙚.

# %%
num = int(input("Enter Number: "))
check = lambda num: "small" if num <50 else "large"
check(num)
# Out:
# Enter Number:  69
# 'large'

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟓 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙬𝙤 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙩𝙝𝙚𝙞𝙧 𝙙𝙞𝙛𝙛𝙚𝙧𝙚𝙣𝙘𝙚 (𝙛𝙞𝙧𝙨𝙩 - 𝙨𝙚𝙘𝙤𝙣𝙙).

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
check = lambda a ,b: a-b
check(a,b)
# Out:
# Enter Number:  9
# Enter Number:  7
# 2

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟔 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 "𝘿𝙞𝙫𝙞𝙨𝙞𝙗𝙡𝙚" 𝙞𝙛 𝙩𝙝𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙨 𝙙𝙞𝙫𝙞𝙨𝙞𝙗𝙡𝙚 𝙗𝙮 𝟓, 𝙤𝙩𝙝𝙚𝙧𝙬𝙞𝙨𝙚 "𝙉𝙤𝙩 𝘿𝙞𝙫𝙞𝙨𝙞𝙗𝙡𝙚".

# %%
num = int(input("Enter Number: "))
check = lambda num: "divisible" if num % 5 ==0 else "not divisible"
check(num)
# Out:
# Enter Number:  250
# 'divisible'

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟕 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙝𝙧𝙚𝙚 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙩𝙝𝙚𝙞𝙧 𝙖𝙫𝙚𝙧𝙖𝙜𝙚.

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
c = int(input("Enter Number: "))
check = lambda a,b,c: (a+b+c)/3
check(a,b,c)
# Out:
# Enter Number:  5
# Enter Number:  10
# Enter Number:  2
# 5.666666666666667

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟖 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙖 𝙣𝙪𝙢𝙗𝙚𝙧 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨: "𝙏𝙚𝙚𝙣" 𝙞𝙛 𝙖𝙜𝙚 𝙞𝙨 𝙗𝙚𝙡𝙤𝙬 𝟏𝟑 "𝙏𝙚𝙚𝙣𝙖𝙜𝙚𝙧" 𝙞𝙛 𝙖𝙜𝙚 𝙞𝙨 𝟏𝟑 𝙩𝙤 𝟏𝟗 "𝘼𝙙𝙪𝙡𝙩" 𝙞𝙛 𝙖𝙜𝙚 𝙞𝙨 𝟐𝟎 𝙤𝙧 𝙖𝙗𝙤𝙫𝙚.

# %%
num = int(input("Enter Number: "))
check = lambda num: "teen"if num < 13 else "teenager" if 20>num >12 else "adult"
check(num)
# Out:
# Enter Number:  55
# 'adult'

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟗 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙬𝙤 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨 𝙩𝙝𝙚 𝙨𝙢𝙖𝙡𝙡𝙚𝙧 𝙣𝙪𝙢𝙗𝙚𝙧.

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
check = lambda a,b: a if a<b else b
check(a,b)
# Out:
# Enter Number:  12
# Enter Number:  42
# 12

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟐𝟎 : 𝘾𝙧𝙚𝙖𝙩𝙚 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙝𝙖𝙩 𝙩𝙖𝙠𝙚𝙨 𝙩𝙝𝙧𝙚𝙚 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙣𝙙 𝙧𝙚𝙩𝙪𝙧𝙣𝙨: "𝘼𝙡𝙡 𝙋𝙤𝙨𝙞𝙩𝙞𝙫𝙚" 𝙞𝙛 𝙖𝙡𝙡 𝙩𝙝𝙧𝙚𝙚 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙖𝙧𝙚 𝙥𝙤𝙨𝙞𝙩𝙞𝙫𝙚 "𝙉𝙤𝙩 𝘼𝙡𝙡 𝙋𝙤𝙨𝙞𝙩𝙞𝙫𝙚" 𝙤𝙩𝙝𝙚𝙧𝙬𝙞𝙨𝙚.

# %%
a = int(input("Enter Number: "))
b = int(input("Enter Number: "))
c = int(input("Enter Number: "))
check = lambda a,b,c: "all positive" if a>0 and b>0 and c>0 else "not all positive"
check(a,b,c)
# Out:
# Enter Number:  7
# Enter Number:  3
# Enter Number:  -1
# 'not all positive'
